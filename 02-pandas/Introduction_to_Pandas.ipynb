# %% [markdown]
# # Series & DataFrames

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('heart-disease.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
series=pd.Series(["BMW","Audi","Mercedes-Benz","Ferrari"])
print(series)

#Series is 1-D 

colors=pd.Series(["Red","blue","yellow","Green"])
print(colors)
# Out:
# 0              BMW
# 1             Audi
# 2    Mercedes-Benz
# 3          Ferrari
# dtype: object
# 0       Red
# 1      blue
# 2    yellow
# 3     Green
# dtype: object

# %%
#Dataframes 2-Dimentional

car_data=pd.DataFrame({"Car Make ":series,"Color":colors})
car_data
# Out:
#        Car Make    Color
# 0            BMW     Red
# 1           Audi    blue
# 2  Mercedes-Benz  yellow
# 3        Ferrari   Green

# %%
#Import data
car_sales=pd.read_csv('car-sales.csv')
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# axis=1 means column
# axis=0 means row
# index number starts 0 by default

# %%
# Exporting a dataframe
car_sales.to_csv('exported-car-sales.csv',index=False) # index=false means to remove added index 
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
#Attribute
car_sales.dtypes

# Funtion
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
# car_sales.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 car_sales.mean()
#
# File c:\coding\ai-ml-ds-bootcamp\.venv\Lib\site-packages\pandas\core\frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)  11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11721     if isinstance(result, Series):
#   11722         result = result.__finalize__(self, method="mean")
#
# File c:\coding\ai-ml-ds-bootcamp\.venv\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# ...

# %%
car_prices=pd.Series([30011,72031,12234])
car_prices.mean()
# Out:
# np.float64(38092.0)

# %%
car_sales.sum()
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %% [markdown]
# ## Viewing And Selecting Data

# %%
car_sales.head()
# gives top 4 rows
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Difference between .loc and .iloc 

animals=pd.Series(["car","dog","bird","panda","snake"],index=[0,3,5,4,3])

# loc refers to index

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# iloc refers to position 

animals.iloc[3] # Integer-location based index
animals.loc[3] # Label (index value) based index
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     car
# 3     dog
# 5    bird
# dtype: object

# %%
car_sales.loc[:3]
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
# car_sales.Odometer (KM)
# it will thorw error as there is a whitespace
# This is the corrected format  
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"]>100000] #Adding Filter
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Compare car Make with number of Doors
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors    Price
# Make
# BMW      11179.000000   5.00  22000.0
# Honda    62778.333333   4.00   6500.0
# Nissan  122347.500000   4.00   6600.0
# Toyota   85451.250000   3.75   5437.5

# %%
# Import matplotlib and tell Jupyter to show plots
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Import matplotlib and tell Jupyter to show plots
# ----> 2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
car_sales["Odometer (KM)"].plot(); # tip: the ";" on the end prevents matplotlib from outputing the plot class

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].dtype
# car_sales["Price"].hist() it will throw error as it was object earlier
# Out:
# <Axes: >

# %%
car_sales['Price'] = (
    car_sales['Price']
    .replace('[$,]', '', regex=True)   # remove $ and commas only
    .astype(float)                     # 4000.00 as float
)

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# np.float64(92302.66666666667)

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)
car_sales_missing

#Tip : inplace=True means it will directly change in the copy of the csv
# Out:
# C:\Users\biswa\AppData\Local\Temp\ipykernel_24896\3330876521.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# ...

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
# car_sales_missing.dropna(inplace=True)
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")
car_sales_missing_dropped=car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %% [markdown]
# ### Column from series

# %%
seats_column=pd.Series([5,5,5,5,5])

#New Column called Seats
car_sales["Seats"]=seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
# we also got some missing values so have to use fillna()
car_sales["Seats"].fillna(5,inplace=True)
car_sales
# Out:
# C:\Users\biswa\AppData\Local\Temp\ipykernel_24896\4267271965.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["Seats"].fillna(5,inplace=True)
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# ...

# %%
# Column from python list

fuel_economy=[7.5,9.2,5.0,9.7,5.5,3.0,6.9,7.0,4.8,9.7]
car_sales["Fuel per 100KM"]=fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel per 100KM
# 0  Toyota  White         150043      4   $4,000.00             7.5
# 1   Honda    Red          87899      4   $5,000.00             9.2
# 2  Toyota   Blue          32549      3   $7,000.00             5.0
# 3     BMW  Black          11179      5  $22,000.00             9.7
# 4  Nissan  White         213095      4   $3,500.00             5.5
# 5  Toyota  Green          99213      4   $4,500.00             3.0
# 6   Honda   Blue          45698      4   $7,500.00             6.9
# 7   Honda   Blue          54738      4   $7,000.00             7.0
# 8  Toyota  White          60000      4   $6,250.00             4.8
# 9  Nissan  White          31600      4   $9,700.00             9.7

# %%
car_sales["Total fuel used(L)"]=car_sales["Odometer (KM)"]/100* car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00             7.5
# 1   Honda    Red          87899      4   $5,000.00             9.2
# 2  Toyota   Blue          32549      3   $7,000.00             5.0
# 3     BMW  Black          11179      5  $22,000.00             9.7
# 4  Nissan  White         213095      4   $3,500.00             5.5
# 5  Toyota  Green          99213      4   $4,500.00             3.0
# 6   Honda   Blue          45698      4   $7,500.00             6.9
# 7   Honda   Blue          54738      4   $7,000.00             7.0
# 8  Toyota  White          60000      4   $6,250.00             4.8
# 9  Nissan  White          31600      4   $9,700.00             9.7
#
#    Total fuel used(L)
# 0           11253.225
# 1            8086.708
# 2            1627.450
# 3            1084.363
# 4           11720.225
# 5            2976.390
# 6            3153.162
# 7            3831.660
# ...

# %%
car_sales["Passed Road Saftey"]=True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00             7.5
# 1   Honda    Red          87899      4   $5,000.00             9.2
# 2  Toyota   Blue          32549      3   $7,000.00             5.0
# 3     BMW  Black          11179      5  $22,000.00             9.7
# 4  Nissan  White         213095      4   $3,500.00             5.5
# 5  Toyota  Green          99213      4   $4,500.00             3.0
# 6   Honda   Blue          45698      4   $7,500.00             6.9
# 7   Honda   Blue          54738      4   $7,000.00             7.0
# 8  Toyota  White          60000      4   $6,250.00             4.8
# 9  Nissan  White          31600      4   $9,700.00             9.7
#
#    Total fuel used(L)  Passed Road Saftey
# 0           11253.225                True
# 1            8086.708                True
# 2            1627.450                True
# 3            1084.363                True
# ...

# %%
car_sales.drop("Passed Road Saftey",axis=1,inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00             7.5
# 1   Honda    Red          87899      4   $5,000.00             9.2
# 2  Toyota   Blue          32549      3   $7,000.00             5.0
# 3     BMW  Black          11179      5  $22,000.00             9.7
# 4  Nissan  White         213095      4   $3,500.00             5.5
# 5  Toyota  Green          99213      4   $4,500.00             3.0
# 6   Honda   Blue          45698      4   $7,500.00             6.9
# 7   Honda   Blue          54738      4   $7,000.00             7.0
# 8  Toyota  White          60000      4   $6,250.00             4.8
# 9  Nissan  White          31600      4   $9,700.00             9.7
#
#    Total fuel used(L)
# 0           11253.225
# 1            8086.708
# 2            1627.450
# 3            1084.363
# 4           11720.225
# 5            2976.390
# 6            3153.162
# 7            3831.660
# ...

# %% [markdown]
# ### Data Manipulation Part 3

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel per 100KM  \
# 8  Toyota  White          60000      4   $6,250.00             4.8
# 1   Honda    Red          87899      4   $5,000.00             9.2
# 5  Toyota  Green          99213      4   $4,500.00             3.0
# 9  Nissan  White          31600      4   $9,700.00             9.7
# 4  Nissan  White         213095      4   $3,500.00             5.5
# 2  Toyota   Blue          32549      3   $7,000.00             5.0
# 0  Toyota  White         150043      4   $4,000.00             7.5
# 3     BMW  Black          11179      5  $22,000.00             9.7
# 6   Honda   Blue          45698      4   $7,500.00             6.9
# 7   Honda   Blue          54738      4   $7,000.00             7.0
#
#    Total fuel used(L)
# 8            2880.000
# 1            8086.708
# 5            2976.390
# 9            3065.200
# 4           11720.225
# 2            1627.450
# 0           11253.225
# 3            1084.363
# ...
